# %%
#load libraries
import pandas as pd     #advanced version of excel. Useful for complex analysis and transformations with just a few lines of code
import matplotlib.pyplot as plt         
import matplotlib.colors as mcolors
from mpl_toolkits import mplot3d
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 #load libraries
# ----> 2 import pandas as pd     #advanced version of excel. Useful for complex analysis and transformations with just a few lines of code
#       3 import matplotlib.pyplot as plt
#       4 import matplotlib.colors as mcolors
#
# ModuleNotFoundError: No module named 'pandas'
